# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load DataSet

# %%
df = pd.read_csv("Monthly_Food_Retail_Price.csv")

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %% [markdown]
# # Know Datasets

# %%
df.head()
# Out:
#                State          Centre Commodity Variety Unit Category  \
# 0     Andhra Pradesh        Chittoor     Moong   Split  Kg.     Food
# 1     Andhra Pradesh          Guntur     Moong   Split  Kg.     Food
# 2     Andhra Pradesh         Kurnool     Moong   Split  Kg.     Food
# 3     Andhra Pradesh  Vishakhapatnam     Moong   Split  Kg.     Food
# 4  Arunachal Pradesh        Itanagar     Moong   Split  Kg.     Food
#
#        Date  Retail Price
# 0  JAN-2001          24.0
# 1  JAN-2001          26.0
# 2  JAN-2001          25.5
# 3  JAN-2001           NaN
# 4  JAN-2001           NaN

# %%
df.tail()
# Out:
#                State      Centre Commodity     Variety Unit Category  \
# 1147441  West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg.     Food
# 1147442  West Bengal     Kolkata     Wheat        Desi  Kg.     Food
# 1147443  West Bengal     Kolkata     Wheat  Kalyan HYV  Kg.     Food
# 1147444  West Bengal       Malda     Wheat        Desi  Kg.     Food
# 1147445  West Bengal       Malda     Wheat  Kalyan HYV  Kg.     Food
#
#              Date  Retail Price
# 1147441  MAR-2021           NaN
# 1147442  MAR-2021           NaN
# 1147443  MAR-2021           NaN
# 1147444  MAR-2021          20.0
# 1147445  MAR-2021           NaN

# %%
df.shape
# Out:
# (1147446, 8)

# %%
df.columns
# Out:
# Index(['State', 'Centre', 'Commodity', 'Variety', 'Unit', 'Category', 'Date',
#        'Retail Price'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Retail Price
# count  578525.000000
# mean       79.691448
# std       148.780859
# min         0.500000
# 25%        18.000000
# 50%        35.000000
# 75%        80.000000
# max     20045.000000

# %%
df.dtypes
# Out:
# State            object
# Centre           object
# Commodity        object
# Variety          object
# Unit             object
# Category         object
# Date             object
# Retail Price    float64
# dtype: object

# %% [markdown]
# # Clean Datasets

# %% [markdown]
# 1)Remove Duplicate Entries
# 2)Remove Category colums

# %%
len(df[df.duplicated()])
# Out:
# 2270

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (1145176, 8)

# %%
df= df.drop("Category",axis=1)

# %% [markdown]
# # Find Null Values & Fill it (if require)

# %% [markdown]
# 1) Drop Raw which has NaN Values for all attributes
# 2) Drop Raw of Comodity attributes which has NaN Value as we cannot get any accurate insights whithout comodity details
# 3) Fill NaN Retail price value with Interpolate Values

# %%
df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity         7450
# Variety         204633
# Unit                 0
# Date                 0
# Retail Price    566853
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 778936

# %%
df.isnull().sum()/(len(df))*100
# Out:
# State            0.000000
# Centre           0.000000
# Commodity        0.650555
# Variety         17.869131
# Unit             0.000000
# Date             0.000000
# Retail Price    49.499204
# dtype: float64

# %%
# REmove Row which has NaN Value of Commodity
df= df.dropna(subset=['Commodity'])
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#              Date  Retail Price
# 0        JAN-2001          24.0
# 1        JAN-2001          26.0
# ...

# %%
df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety         203148
# Unit                 0
# Date                 0
# Retail Price    563982
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 767130

# %%
df[df.Variety.isnull()]
# Out:
#                      State          Centre    Commodity Variety      Unit  \
# 86          Andhra Pradesh        Chittoor  Mustard Oil     NaN  Kg/Litre
# 87          Andhra Pradesh          Guntur  Mustard Oil     NaN  Kg/Litre
# 88          Andhra Pradesh         Kurnool  Mustard Oil     NaN  Kg/Litre
# 89          Andhra Pradesh  Vishakhapatnam  Mustard Oil     NaN  Kg/Litre
# 90       Arunachal Pradesh        Itanagar  Mustard Oil     NaN  Kg/Litre
# ...                    ...             ...          ...     ...       ...
# 1147276        Uttarakhand        Srinagar    Vanaspati     NaN  Kg/Litre
# 1147277        West Bengal         Asansol    Vanaspati     NaN  Kg/Litre
# 1147278        West Bengal          Howrah    Vanaspati     NaN  Kg/Litre
# 1147279        West Bengal      Jalpaiguri    Vanaspati     NaN  Kg/Litre
# 1147280        West Bengal         Kolkata    Vanaspati     NaN  Kg/Litre
#
#              Date  Retail Price
# 86       JAN-2001           NaN
# ...

# %%
miss_df = df[df["Retail Price"].isnull()]

# %%
miss_df["Commodity"].value_counts()
# Out:
# Fish             33806
# Rice             28687
# Coffee           25650
# Coconut          24166
# Wheat            23288
# Tea              22464
# Salt             20677
# Milk             19296
# Gram             18806
# Gingelly Oil     11699
# Apple            10700
# Maize            10293
# Groundnut Oil    10195
# Vanaspati        10144
# Coconut Oil      10124
# Biscuit           9952
# Butter            9918
# Ragi              9846
# Mustard Oil       9777
# Jowar             9771
# Bread             9730
# Cummin Seed       9693
# Besan             9632
# Masur             9566
# Ghee              9379
# Black Pepper      9170
# Chicken           9147
# Bajra             9147
# Maida             9077
# Coriander         9057
# Brinjal           9012
# Banana            9005
# Suji              8997
# Urad              8971
# Red Chillies      8970
# Atta              8958
# Eggs              8951
# Meat              8853
# Turmeric          8825
# Tomato            8765
# ...

# %%
miss_df["State"].value_counts()
# Out:
# Madhya Pradesh       54942
# Maharashtra          44207
# Tamil Nadu           37179
# Bihar                34430
# Gujarat              33609
# Union Territories    33217
# Assam                32090
# Karnataka            27376
# West Bengal          26839
# Uttar Pradesh        25493
# Uttarakhand          25233
# Rajasthan            22393
# Punjab               21407
# Orissa               18244
# Jammu Kashmir        15064
# Himachal Pradesh     14188
# Andhra Pradesh       13613
# Sikkim               12502
# Haryana              11333
# Arunachal Pradesh    10057
# Jharkhand             8608
# Nagaland              8235
# Kerala                7485
# Manipur               6001
# Meghalaya             4025
# National Capital      3900
# Tripura               3768
# Goa                   3407
# Mizoram               3139
# Telangana             1998
# Name: State, dtype: int64

# %%
df["Retail Price"].describe()
# Out:
# count    573744.000000
# mean         79.733410
# std         148.982351
# min           0.500000
# 25%          18.000000
# 50%          35.000000
# 75%          80.000000
# max       20045.000000
# Name: Retail Price, dtype: float64

# %%
# Drop Row with All NaN Value
df1=df.dropna(how='all')
df1
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#              Date  Retail Price
# 0        JAN-2001          24.0
# 1        JAN-2001          26.0
# ...

# %%
df1.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety         203148
# Unit                 0
# Date                 0
# Retail Price    563982
# dtype: int64

# %%
# Fill Null Retail Price Value with Interpolate Method
Reatil_Price_df = df.interpolate()
Reatil_Price_df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#              Date  Retail Price
# 0        JAN-2001       24.0000
# 1        JAN-2001       26.0000
# ...

# %%
Reatil_Price_df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety         203148
# Unit                 0
# Date                 0
# Retail Price         0
# dtype: int64

# %% [markdown]
# # Save the clean data in CSV and JSON format

# %%
Reatil_Price_df.to_csv(r'E:\Python Lab\Projects\Monthly_Retails_Price_Clean.csv')

# %%
Reatil_Price_df.to_json(r'E:\Python Lab\Projects\Monthly_Retails_PriceClean.json')

# %% [markdown]
# # Load Clean DataSet

# %%
df_Clean = pd.read_csv("Monthly_Retails_Price_Clean.csv")
df_Clean
# Out:
#          Unnamed: 0              State          Centre Commodity     Variety  \
# 0                 0     Andhra Pradesh        Chittoor     Moong       Split
# 1                 1     Andhra Pradesh          Guntur     Moong       Split
# 2                 2     Andhra Pradesh         Kurnool     Moong       Split
# 3                 3     Andhra Pradesh  Vishakhapatnam     Moong       Split
# 4                 4  Arunachal Pradesh        Itanagar     Moong       Split
# ...             ...                ...             ...       ...         ...
# 1137721     1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV
# 1137722     1147442        West Bengal         Kolkata     Wheat        Desi
# 1137723     1147443        West Bengal         Kolkata     Wheat  Kalyan HYV
# 1137724     1147444        West Bengal           Malda     Wheat        Desi
# 1137725     1147445        West Bengal           Malda     Wheat  Kalyan HYV
#
#         Unit      Date  Retail Price
# ...

# %%
#Change datatype of Date Fetures
df_Clean['Date']= df_Clean['Date'].astype('datetime64[ns]')

# %%
df_Clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1137726 entries, 0 to 1137725
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1137726 non-null  int64
#  1   State         1137726 non-null  object
#  2   Centre        1137726 non-null  object
#  3   Commodity     1137726 non-null  object
#  4   Variety       934578 non-null   object
#  5   Unit          1137726 non-null  object
#  6   Date          1137726 non-null  datetime64[ns]
#  7   Retail Price  1137726 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 69.4+ MB

# %%
df_Clean.dtypes
# Out:
# Unnamed: 0               int64
# State                   object
# Centre                  object
# Commodity               object
# Variety                 object
# Unit                    object
# Date            datetime64[ns]
# Retail Price           float64
# dtype: object

# %%
#Add Year Features 
df_Clean['Year'] = df_Clean['Date'].dt.year
df_Clean
# Out:
#          Unnamed: 0              State          Centre Commodity     Variety  \
# 0                 0     Andhra Pradesh        Chittoor     Moong       Split
# 1                 1     Andhra Pradesh          Guntur     Moong       Split
# 2                 2     Andhra Pradesh         Kurnool     Moong       Split
# 3                 3     Andhra Pradesh  Vishakhapatnam     Moong       Split
# 4                 4  Arunachal Pradesh        Itanagar     Moong       Split
# ...             ...                ...             ...       ...         ...
# 1137721     1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV
# 1137722     1147442        West Bengal         Kolkata     Wheat        Desi
# 1137723     1147443        West Bengal         Kolkata     Wheat  Kalyan HYV
# 1137724     1147444        West Bengal           Malda     Wheat        Desi
# 1137725     1147445        West Bengal           Malda     Wheat  Kalyan HYV
#
#         Unit       Date  Retail Price  Year
# ...

# %%
df_Clean = df_Clean.drop("Unnamed: 0",axis=1)
df_Clean
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1137721        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1137722        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1137723        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1137724        West Bengal           Malda     Wheat        Desi  Kg.
# 1137725        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#               Date  Retail Price  Year
# 0       2001-01-01       24.0000  2001
# 1       2001-01-01       26.0000  2001
# ...

# %%
df_Clean.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity            0
# Variety         203148
# Unit                 0
# Date                 0
# Retail Price         0
# Year                 0
# dtype: int64

# %%
df_Clean.Commodity.unique()
# Out:
# array(['Moong', 'Mustard Oil', 'Onion', 'Potato', 'Ragi', 'Red Chillies',
#        'Rice', 'Salt', 'Sugar', 'Suji', 'Tea', 'Apple', 'Arhar', 'Atta',
#        'Bajra', 'Banana', 'Besan', 'Biscuit', 'Groundnut Oil', 'Gur',
#        'Jowar', 'Maida', 'Maize', 'Masur', 'Meat', 'Milk', 'Coriander',
#        'Cummin Seed', 'Eggs', 'Fish', 'Ghee', 'Gingelly Oil', 'Gram',
#        'Black Pepper', 'Bread', 'Brinjal', 'Butter', 'Chicken', 'Coconut',
#        'Coconut Oil', 'Coffee', 'Tomato', 'Turmeric', 'Urad', 'Vanaspati',
#        'Wheat'], dtype=object)

# %% [markdown]
# # Which Date has highest price of wheat?

# %%
df2_list = ['Wheat']
Commodity_Wheat= df_Clean[df_Clean.Commodity.isin(df2_list)]
Commodity_Wheat
# Out:
#                   State      Centre Commodity     Variety Unit       Date  \
# 1016078  Andhra Pradesh    Chittoor     Wheat        Desi  Kg. 2001-01-01
# 1016079  Andhra Pradesh    Chittoor     Wheat  Kalyan HYV  Kg. 2001-01-01
# 1016080  Andhra Pradesh      Guntur     Wheat        Desi  Kg. 2001-01-01
# 1016081  Andhra Pradesh      Guntur     Wheat  Kalyan HYV  Kg. 2001-01-01
# 1016082  Andhra Pradesh     Kurnool     Wheat        Desi  Kg. 2001-01-01
# ...                 ...         ...       ...         ...  ...        ...
# 1137721     West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg. 2021-03-01
# 1137722     West Bengal     Kolkata     Wheat        Desi  Kg. 2021-03-01
# 1137723     West Bengal     Kolkata     Wheat  Kalyan HYV  Kg. 2021-03-01
# 1137724     West Bengal       Malda     Wheat        Desi  Kg. 2021-03-01
# 1137725     West Bengal       Malda     Wheat  Kalyan HYV  Kg. 2021-03-01
#
#          Retail Price  Year
# 1016078     13.000000  2001
# ...

# %%
Commodity_Wheat.max()
# Out:
# State                   West Bengal
# Centre               Vishakhapatnam
# Commodity                     Wheat
# Variety                  Kalyan HYV
# Unit                            Kg.
# Date            2021-03-01 00:00:00
# Retail Price                  130.0
# Year                           2021
# dtype: object

# %%
Datewise_Wheat_Price= Commodity_Wheat.groupby(['Commodity','Year'])['Retail Price'].max()
Datewise_Wheat_Price
# Out:
# Commodity  Year
# Wheat      2001     18.500000
#            2002     33.833333
#            2003     20.000000
#            2004     38.000000
#            2005     25.000000
#            2006     25.000000
#            2007     45.000000
#            2008     43.000000
#            2009     30.000000
#            2010     50.000000
#            2011     50.000000
#            2012     50.000000
#            2013     77.200000
#            2014     56.000000
#            2015     66.000000
#            2016     66.000000
#            2017     70.000000
#            2018     50.000000
#            2019     66.000000
#            2020    125.000000
#            2021    130.000000
# Name: Retail Price, dtype: float64

# %% [markdown]
# # Which is the highest price of wheat state wise?

# %%
Statewise_Wheat_Price= Commodity_Wheat.groupby(['Commodity','State'])['Retail Price'].max()
Statewise_Wheat_Price
# Out:
# Commodity  State
# Wheat      Andhra Pradesh        77.200000
#            Arunachal Pradesh     54.800000
#            Assam                 49.200000
#            Bihar                 30.666667
#            Goa                   36.000000
#            Gujarat               36.000000
#            Haryana               28.888889
#            Himachal Pradesh      30.055556
#            Jammu Kashmir         31.611111
#            Jharkhand             32.000000
#            Karnataka             70.000000
#            Kerala                44.000000
#            Madhya Pradesh        35.272727
#            Maharashtra           40.000000
#            Manipur               33.666667
#            Meghalaya             33.285714
#            Nagaland              33.571429
#            National Capital      33.857143
#            Orissa                36.000000
#            Punjab                33.714286
#            Rajasthan             36.285714
# ...

# %%
Statewise_Wheat_Price.plot(kind="bar",figsize=(16,4))
plt.title("Highest Price of Wheat Statewise")
plt.show()

# %% [markdown]
# # If the Commodity is mustard oil, how many varieties are available in mustard oil

# %%
df1_list = ['Mustard Oil']
Variety_Musterd_Oil= df_Clean[df_Clean.Commodity.isin(df1_list)]
Variety_Musterd_Oil
# Out:
#                     State          Centre    Commodity Variety      Unit  \
# 85         Andhra Pradesh        Chittoor  Mustard Oil     NaN  Kg/Litre
# 86         Andhra Pradesh          Guntur  Mustard Oil     NaN  Kg/Litre
# 87         Andhra Pradesh         Kurnool  Mustard Oil     NaN  Kg/Litre
# 88         Andhra Pradesh  Vishakhapatnam  Mustard Oil     NaN  Kg/Litre
# 89      Arunachal Pradesh        Itanagar  Mustard Oil     NaN  Kg/Litre
# ...                   ...             ...          ...     ...       ...
# 301455        Uttarakhand        Srinagar  Mustard Oil     NaN  Kg/Litre
# 301456        West Bengal         Asansol  Mustard Oil     NaN  Kg/Litre
# 301457        West Bengal          Howrah  Mustard Oil     NaN  Kg/Litre
# 301458        West Bengal      Jalpaiguri  Mustard Oil     NaN  Kg/Litre
# 301459        West Bengal         Kolkata  Mustard Oil     NaN  Kg/Litre
#
#              Date  Retail Price  Year
# 85     2001-01-01     39.333333  2001
# ...

# %%
Variety_Musterd_Oil.Variety.unique().tolist()
# Out:
# [nan]

# %% [markdown]
# # How many varieties are available in each commodity

# %%
Variety_All= df_Clean.groupby('Commodity').Variety.unique()
Variety_All
# Out:
# Commodity
# Apple                        [Delicious medium size]
# Arhar                                        [Split]
# Atta                                           [FAQ]
# Bajra                                          [FAQ]
# Banana                                         [FAQ]
# Besan                                          [nan]
# Biscuit                                    [Glucose]
# Black Pepper                                 [Whole]
# Bread                                        [Local]
# Brinjal                                        [FAQ]
# Butter                              [Amul/Any Other]
# Chicken                                    [Poultry]
# Coconut                                 [Dry, Fresh]
# Coconut Oil                                    [nan]
# Coffee                           [Instant, Powdered]
# Coriander                          [Powdered Agmark]
# Cummin Seed                                 [Common]
# ...

# %% [markdown]
# # What is the Pomphret price in kerala from 2001 to 2021?

# %%
Pomphret_Price= df_Clean[(df_Clean['Year']<= 2021) & (df_Clean['State']=='Kerala') & (df_Clean['Variety']=='Pomphret')]
Pomphret_Price
# Out:
#          State      Centre Commodity   Variety Unit       Date  Retail Price  \
# 621913  Kerala   Ernakulam      Fish  Pomphret  Kg. 2001-01-01     37.066667
# 621916  Kerala  Khozhikode      Fish  Pomphret  Kg. 2001-01-01     44.666667
# 621919  Kerala  Trivandrum      Fish  Pomphret  Kg. 2001-01-01     52.266667
# 622710  Kerala   Ernakulam      Fish  Pomphret  Kg. 2001-02-01     37.066667
# 622713  Kerala  Khozhikode      Fish  Pomphret  Kg. 2001-02-01     44.666667
# ...        ...         ...       ...       ...  ...        ...           ...
# 813993  Kerala  Khozhikode      Fish  Pomphret  Kg. 2021-02-01    500.000000
# 813996  Kerala  Trivandrum      Fish  Pomphret  Kg. 2021-02-01    650.000000
# 814787  Kerala   Ernakulam      Fish  Pomphret  Kg. 2021-03-01    199.000000
# 814790  Kerala  Khozhikode      Fish  Pomphret  Kg. 2021-03-01    500.000000
# 814793  Kerala  Trivandrum      Fish  Pomphret  Kg. 2021-03-01    650.000000
#
#         Year
# 621913  2001
# 621916  2001
# ...

# %%
Pomphret_Price = Pomphret_Price[['Year','Variety','Retail Price']]
Pomphret_Price
# Out:
#         Year   Variety  Retail Price
# 621913  2001  Pomphret     37.066667
# 621916  2001  Pomphret     44.666667
# 621919  2001  Pomphret     52.266667
# 622710  2001  Pomphret     37.066667
# 622713  2001  Pomphret     44.666667
# ...      ...       ...           ...
# 813993  2021  Pomphret    500.000000
# 813996  2021  Pomphret    650.000000
# 814787  2021  Pomphret    199.000000
# 814790  2021  Pomphret    500.000000
# 814793  2021  Pomphret    650.000000
#
# [729 rows x 3 columns]

# %%
x= Pomphret_Price.pivot_table(index='Year',columns='Variety')
x
# Out:
#         Retail Price
# Variety     Pomphret
# Year
# 2001       42.335648
# 2002       45.116597
# 2003       70.895791
# 2004       88.094507
# 2005       89.945988
# 2006      110.416667
# 2007      111.562500
# 2008      158.838384
# 2009      155.833333
# 2010      181.111111
# 2011      155.081369
# 2012      195.524691
# 2013      150.470514
# 2014      151.935626
# 2015      273.148148
# 2016      412.053953
# 2017      404.611111
# 2018      418.564815
# 2019      452.129630
# 2020      396.328704
# 2021      449.888889

# %%
x.plot(kind="bar",figsize=(16,4))
plt.title("Yearwise Pomphret price of kerala")
plt.show()

# %% [markdown]
# # How many states has meat as commodity?

# %%
df7_list = ['Meat']
Commodity_Meat= df_Clean[df_Clean.Commodity.isin(df7_list)]
Commodity_Meat
# Out:
#                     State          Centre Commodity Variety Unit       Date  \
# 442502     Andhra Pradesh        Chittoor      Meat  Mutton  Kg. 2001-01-01
# 442503     Andhra Pradesh          Guntur      Meat  Mutton  Kg. 2001-01-01
# 442504     Andhra Pradesh         Kurnool      Meat  Mutton  Kg. 2001-01-01
# 442505     Andhra Pradesh  Vishakhapatnam      Meat  Mutton  Kg. 2001-01-01
# 442506  Arunachal Pradesh        Itanagar      Meat  Mutton  Kg. 2001-01-01
# ...                   ...             ...       ...     ...  ...        ...
# 621419        Uttarakhand        Srinagar      Meat  Mutton  Kg. 2021-03-01
# 621420        West Bengal         Asansol      Meat  Mutton  Kg. 2021-03-01
# 621421        West Bengal          Howrah      Meat  Mutton  Kg. 2021-03-01
# 621422        West Bengal      Jalpaiguri      Meat  Mutton  Kg. 2021-03-01
# 621423        West Bengal         Kolkata      Meat  Mutton  Kg. 2021-03-01
#
#         Retail Price  Year
# 442502    120.000000  2001
# ...

# %%
Statewise_Meat= Commodity_Meat.groupby('Commodity').State.unique().tolist()
Statewise_Meat
# Out:
# [array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Goa',
#         'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu Kashmir',
#         'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#         'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#         'National Capital', 'Orissa', 'Punjab', 'Rajasthan', 'Sikkim',
#         'Tamil Nadu', 'Telangana', 'Tripura', 'Union Territories',
#         'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)]

# %% [markdown]
# # How many types of variety of meat?

# %%
Commodity_Meat.Variety.unique()
# Out:
# array(['Mutton'], dtype=object)

# %% [markdown]
# # Which Centre has the highest price of rice in Maharashtra?

# %%
Commodity_Rice_MH = df_Clean[(df_Clean['Commodity'] == 'Rice') & (df_Clean['State'] == 'Maharashtra')]
Commodity_Rice_MH
# Out:
#               State      Centre Commodity        Variety Unit       Date  \
# 601     Maharashtra  Aurangabad      Rice  Common/Coarse  Kg. 2001-01-01
# 602     Maharashtra  Aurangabad      Rice           Fine  Kg. 2001-01-01
# 603     Maharashtra  Aurangabad      Rice      Superfine  Kg. 2001-01-01
# 604     Maharashtra      Mumbai      Rice  Common/Coarse  Kg. 2001-01-01
# 605     Maharashtra      Mumbai      Rice           Fine  Kg. 2001-01-01
# ...             ...         ...       ...            ...  ...        ...
# 301901  Maharashtra       Nasik      Rice           Fine  Kg. 2021-03-01
# 301902  Maharashtra       Nasik      Rice      Superfine  Kg. 2021-03-01
# 301903  Maharashtra        Pune      Rice  Common/Coarse  Kg. 2021-03-01
# 301904  Maharashtra        Pune      Rice           Fine  Kg. 2021-03-01
# 301905  Maharashtra        Pune      Rice      Superfine  Kg. 2021-03-01
#
#         Retail Price  Year
# 601        15.272727  2001
# 602        14.909091  2001
# ...

# %%
Centre_Commodity_Rice_MH = Commodity_Rice_MH.groupby('Centre')['Retail Price'].max()
Centre_Commodity_Rice_MH
# Out:
# Centre
# Aurangabad    122.0
# Mumbai         84.0
# Nagpur         66.0
# Nasik          75.0
# Pune           75.0
# Name: Retail Price, dtype: float64

# %%
Centre_Commodity_Rice_MH.plot(kind="bar")
plt.title("Maharashtra Rice Max Price Centrewise")
plt.show()

# %% [markdown]
# # What is the price difference between desi wheat and kalyan HYV state wise

# %%
Commodity_Wheat = df_Clean[(df_Clean['Commodity'] == 'Wheat')]
Commodity_Wheat
# Out:
#                   State      Centre Commodity     Variety Unit       Date  \
# 1016078  Andhra Pradesh    Chittoor     Wheat        Desi  Kg. 2001-01-01
# 1016079  Andhra Pradesh    Chittoor     Wheat  Kalyan HYV  Kg. 2001-01-01
# 1016080  Andhra Pradesh      Guntur     Wheat        Desi  Kg. 2001-01-01
# 1016081  Andhra Pradesh      Guntur     Wheat  Kalyan HYV  Kg. 2001-01-01
# 1016082  Andhra Pradesh     Kurnool     Wheat        Desi  Kg. 2001-01-01
# ...                 ...         ...       ...         ...  ...        ...
# 1137721     West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg. 2021-03-01
# 1137722     West Bengal     Kolkata     Wheat        Desi  Kg. 2021-03-01
# 1137723     West Bengal     Kolkata     Wheat  Kalyan HYV  Kg. 2021-03-01
# 1137724     West Bengal       Malda     Wheat        Desi  Kg. 2021-03-01
# 1137725     West Bengal       Malda     Wheat  Kalyan HYV  Kg. 2021-03-01
#
#          Retail Price  Year
# 1016078     13.000000  2001
# ...

# %%
Commodity_Wheat = Commodity_Wheat[['State','Variety','Retail Price']]
Commodity_Wheat
# Out:
#                   State     Variety  Retail Price
# 1016078  Andhra Pradesh        Desi     13.000000
# 1016079  Andhra Pradesh  Kalyan HYV     10.000000
# 1016080  Andhra Pradesh        Desi     11.500000
# 1016081  Andhra Pradesh  Kalyan HYV     11.333333
# 1016082  Andhra Pradesh        Desi     11.166667
# ...                 ...         ...           ...
# 1137721     West Bengal  Kalyan HYV     24.200000
# 1137722     West Bengal        Desi     22.800000
# 1137723     West Bengal  Kalyan HYV     21.400000
# 1137724     West Bengal        Desi     20.000000
# 1137725     West Bengal  Kalyan HYV     20.000000
#
# [39852 rows x 3 columns]

# %%
Commodity_Wheat.pivot_table(index='State',columns='Variety')
# Out:
#                   Retail Price
# Variety                   Desi Kalyan HYV
# State
# Andhra Pradesh       23.230896  23.306971
# Arunachal Pradesh    20.985217  20.062489
# Assam                18.156191  18.919556
# Bihar                17.548393  17.121226
# Goa                  21.971071  20.478643
# Gujarat              17.527915  17.354019
# Haryana              14.439864  13.841952
# Himachal Pradesh     14.497045  14.356321
# Jammu Kashmir        14.753186  14.948069
# Jharkhand            16.788587  16.843845
# Karnataka            21.897704  22.029795
# Kerala               22.753970  20.373268
# Madhya Pradesh       18.518742  17.938276
# Maharashtra          21.261653  20.496901
# Manipur                    NaN  19.082510
# Meghalaya                  NaN  18.681709
# Nagaland             18.120072  17.354319
# National Capital     16.663463  15.574059
# Orissa               18.926050  17.170920
# Punjab               15.246224  14.870118
# ...

# %% [markdown]
# # Price range in year wise

# %%
Yearwise_PriceRange=df_Clean.groupby('Year')['Retail Price'].agg(["min","max"]) 
Yearwise_PriceRange
# Out:
#        min      max
# Year
# 2001  1.25   1300.0
# 2002  1.75    540.0
# 2003  1.60    902.0
# 2004  2.00   5300.0
# 2005  0.50   1100.0
# 2006  1.00   4120.0
# 2007  2.00   1500.0
# 2008  2.00   1700.0
# 2009  1.00   1850.0
# 2010  3.00   8400.0
# 2011  3.00  20045.0
# 2012  3.00   2800.0
# 2013  1.00   8200.0
# 2014  2.00   3200.0
# 2015  1.00   4550.0
# 2016  3.00   9285.0
# 2017  3.00   2800.0
# 2018  3.00   1900.0
# 2019  3.00   2600.0
# 2020  3.00   2750.0
# 2021  3.00  20000.0

# %%
YearCommoditywise_PriceRange=df_Clean.groupby(['Year','Commodity'])['Retail Price'].agg(["min","max"]) 
YearCommoditywise_PriceRange
# Out:
#                       min         max
# Year Commodity
# 2001 Apple       7.441860  267.105882
#      Arhar      16.333333   38.000000
#      Atta        6.000000   21.000000
#      Bajra       3.500000   14.000000
#      Banana      4.000000   31.250000
# ...                   ...         ...
# 2021 Tomato      9.000000   80.000000
#      Turmeric   15.000000   35.000000
#      Urad       75.000000  152.500000
#      Vanaspati  78.000000  150.000000
#      Wheat      17.500000  130.000000
#
# [966 rows x 2 columns]

# %% [markdown]
# # How many varieties of coffee is available and what is their price differences (Year Wise)?

# %%
Coffee = df_Clean[df_Clean['Commodity'] == 'Coffee']
Coffee
# Out:
#                   State      Centre Commodity   Variety        Unit  \
# 815936   Andhra Pradesh    Chittoor    Coffee   Instant  500gm. Pkt
# 815937   Andhra Pradesh    Chittoor    Coffee  Powdered         Kg.
# 815938   Andhra Pradesh      Guntur    Coffee   Instant  500gm. Pkt
# 815939   Andhra Pradesh      Guntur    Coffee  Powdered         Kg.
# 815940   Andhra Pradesh     Kurnool    Coffee   Instant  500gm. Pkt
# ...                 ...         ...       ...       ...         ...
# 1015735     West Bengal  Jalpaiguri    Coffee  Powdered         Kg.
# 1015736     West Bengal     Kolkata    Coffee   Instant  500gm. Pkt
# 1015737     West Bengal     Kolkata    Coffee  Powdered         Kg.
# 1015738     West Bengal       Malda    Coffee   Instant  500gm. Pkt
# 1015739     West Bengal       Malda    Coffee  Powdered         Kg.
#
#               Date  Retail Price  Year
# 815936  2001-01-01    105.000000  2001
# 815937  2001-01-01    140.000000  2001
# ...

# %%
Coffee.Variety.unique()
# Out:
# array(['Instant', 'Powdered'], dtype=object)

# %%
Coffee_PriceDiff = Coffee.groupby('Year')['Retail Price'].agg(["min","max"])
Coffee_PriceDiff
# Out:
#        min      max
# Year
# 2001  43.5    190.0
# 2002  42.0    540.0
# 2003  95.0    195.0
# 2004  15.0   1100.0
# 2005  14.0   1100.0
# 2006   9.0   1100.0
# 2007  17.0   1500.0
# 2008  18.0   1700.0
# 2009  20.0   1850.0
# 2010  30.0   1400.0
# 2011  34.0   1400.0
# 2012  58.0   2800.0
# 2013  74.0   8200.0
# 2014   3.0   3200.0
# 2015   1.0   3200.0
# 2016  73.0   9285.0
# 2017  85.0   2800.0
# 2018  60.0   1900.0
# 2019  60.0   2600.0
# 2020  53.0   2750.0
# 2021  53.0  20000.0

# %% [markdown]
# # What are the varieties of fish available in the market from 2001 to 2010?

# %%
Period= df_Clean[(df_Clean['Year']<= 2010) & (df_Clean['Commodity']=='Fish')]
Period
Period.Variety.unique()
# Out:
# array(['Cat Fish', 'Pomphret', 'Rohu 1Kg Size'], dtype=object)

# %% [markdown]
# # Which state has lowest price of Bajra according to year wise?

# %%
Bajra = df_Clean[df_Clean['Commodity']=='Bajra']
Bajra
# Out:
#                  State          Centre Commodity Variety Unit       Date  \
# 302787  Andhra Pradesh        Chittoor     Bajra     FAQ  Kg. 2001-01-01
# 302788  Andhra Pradesh          Guntur     Bajra     FAQ  Kg. 2001-01-01
# 302789  Andhra Pradesh         Kurnool     Bajra     FAQ  Kg. 2001-01-01
# 302790  Andhra Pradesh  Vishakhapatnam     Bajra     FAQ  Kg. 2001-01-01
# 302791           Assam          Dispur     Bajra     FAQ  Kg. 2001-01-01
# ...                ...             ...       ...     ...  ...        ...
# 441759   Uttar Pradesh      Saharanpur     Bajra     FAQ  Kg. 2021-03-01
# 441760     Uttarakhand        Haldwani     Bajra     FAQ  Kg. 2021-03-01
# 441761     Uttarakhand        Srinagar     Bajra     FAQ  Kg. 2021-03-01
# 441762     West Bengal         Asansol     Bajra     FAQ  Kg. 2021-03-01
# 441763     West Bengal          Howrah     Bajra     FAQ  Kg. 2021-03-01
#
#         Retail Price  Year
# 302787          6.50  2001
# 302788          5.75  2001
# ...

# %%
Bajra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16767 entries, 302787 to 441763
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         16767 non-null  object
#  1   Centre        16767 non-null  object
#  2   Commodity     16767 non-null  object
#  3   Variety       16767 non-null  object
#  4   Unit          16767 non-null  object
#  5   Date          16767 non-null  datetime64[ns]
#  6   Retail Price  16767 non-null  float64
#  7   Year          16767 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 1.2+ MB

# %%
Bajra = Bajra[['State','Year','Retail Price']]
Bajra
# Out:
#                  State  Year  Retail Price
# 302787  Andhra Pradesh  2001          6.50
# 302788  Andhra Pradesh  2001          5.75
# 302789  Andhra Pradesh  2001          5.00
# 302790  Andhra Pradesh  2001          5.80
# 302791           Assam  2001          6.60
# ...                ...   ...           ...
# 441759   Uttar Pradesh  2021         19.00
# 441760     Uttarakhand  2021         20.00
# 441761     Uttarakhand  2021         21.00
# 441762     West Bengal  2021         22.00
# 441763     West Bengal  2021         31.00
#
# [16767 rows x 3 columns]

# %%
Bajra.pivot_table(index='State',columns='Year',aggfunc='min')
# Out:
#                   Retail Price                                            \
# Year                      2001      2002      2003       2004       2005
# State
# Andhra Pradesh        5.000000  6.000000  7.000000   6.000000   7.000000
# Assam                 6.600000  6.800000  8.142857   6.166667   7.750000
# Bihar                 7.025000  7.600000  8.714286   6.333333   9.250000
# Goa                   7.112500  7.440000  9.000000   6.416667  10.000000
# Gujarat               5.200000  5.375000  5.800000   6.000000   7.000000
# Haryana               5.000000  5.000000  5.500000   5.000000   6.500000
# Himachal Pradesh      5.400000  5.400000  6.000000   5.333333   6.750000
# Jammu Kashmir         5.800000  5.800000  6.500000   5.666667   6.250000
# Jharkhand             6.000000  6.000000  6.850000   6.000000   6.000000
# Karnataka             6.000000  5.928571  7.000000   5.500000   5.500000
# Kerala                6.041667  5.357143  7.000000   5.909091   6.500000
# ...

# %%
Statewise_Bajra_LowestPrice=Bajra.groupby(['Year','State'])['Retail Price'].min()
Statewise_Bajra_LowestPrice
# Out:
# Year  State
# 2001  Andhra Pradesh        5.0000
#       Assam                 6.6000
#       Bihar                 7.0250
#       Goa                   7.1125
#       Gujarat               5.2000
#                             ...
# 2021  Telangana            27.0000
#       Union Territories    19.5000
#       Uttar Pradesh        17.0000
#       Uttarakhand          20.0000
#       West Bengal          22.0000
# Name: Retail Price, Length: 567, dtype: float64

# %% [markdown]
# # How many types of oils are available and their varieties?

# %%
df_Clean.Commodity.unique()
# Out:
# array(['Moong', 'Mustard Oil', 'Onion', 'Potato', 'Ragi', 'Red Chillies',
#        'Rice', 'Salt', 'Sugar', 'Suji', 'Tea', 'Apple', 'Arhar', 'Atta',
#        'Bajra', 'Banana', 'Besan', 'Biscuit', 'Groundnut Oil', 'Gur',
#        'Jowar', 'Maida', 'Maize', 'Masur', 'Meat', 'Milk', 'Coriander',
#        'Cummin Seed', 'Eggs', 'Fish', 'Ghee', 'Gingelly Oil', 'Gram',
#        'Black Pepper', 'Bread', 'Brinjal', 'Butter', 'Chicken', 'Coconut',
#        'Coconut Oil', 'Coffee', 'Tomato', 'Turmeric', 'Urad', 'Vanaspati',
#        'Wheat'], dtype=object)

# %%
df2_list = [' Oil']
Variety_Oil= df_Clean[df_Clean.Commodity.isin(df2_list)]
Variety_Oil
# Out:
# Empty DataFrame
# Columns: [State, Centre, Commodity, Variety, Unit, Date, Retail Price, Year]
# Index: []

# %% [markdown]
# # Top 5 Commodities which have high retail price in 2021

# %%
Year_2021 = df_Clean[df_Clean['Year'] == 2021]
Year_2021
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 298800      Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 298801      Andhra Pradesh          Guntur     Moong       Split  Kg.
# 298802      Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 298803      Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 298804   Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1137721        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1137722        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1137723        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1137724        West Bengal           Malda     Wheat        Desi  Kg.
# 1137725        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#               Date  Retail Price  Year
# 298800  2021-01-01    105.000000  2021
# 298801  2021-01-01    105.000000  2021
# ...

# %%
Top5_Commodity= Year_2021.groupby('Commodity')['Retail Price'].max().sort_values(ascending= False)
Top5_Commodity [ :5]
# Out:
# Commodity
# Coffee          20000.0
# Meat             1200.0
# Fish             1100.0
# Black Pepper     1000.0
# Ghee              820.0
# Name: Retail Price, dtype: float64

# %%
Top5_Commodity[ :5].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Commodity'>

# %% [markdown]
# # Conclusion Of Project

# %%
from pandas_profiling import ProfileReport

# %%
prof = ProfileReport(Reatil_Price_df)

# %%
prof.to_file("EDA_report_Monthly Retail Price.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prof1 = ProfileReport(df_Clean)

# %%
prof1.to_file("EDA_report_Monthly Retail Price1.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
