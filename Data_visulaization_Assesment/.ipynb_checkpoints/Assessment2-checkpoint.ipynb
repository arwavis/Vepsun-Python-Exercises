# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('FitBit_data.csv')
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df = df.drop(['Id','TrackerDistance', ], axis= 1)

# %%
df
# Out:
#     ActivityDate  TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# 0      3/25/2016       11004       7.110000                       0.0
# 1      3/26/2016       17609      11.550000                       0.0
# 2      3/27/2016       12736       8.530000                       0.0
# 3      3/28/2016       13231       8.930000                       0.0
# 4      3/29/2016       12041       7.850000                       0.0
# ..           ...         ...            ...                       ...
# 452     4/8/2016       23014      20.389999                       0.0
# 453     4/9/2016       16470       8.070000                       0.0
# 454    4/10/2016       28497      27.530001                       0.0
# 455    4/11/2016       10622       8.060000                       0.0
# 456    4/12/2016        2350       1.780000                       0.0
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
df.shape
# Out:
# (457, 13)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 5941

# %%
df.dtypes
# Out:
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ActivityDate              457 non-null    object
#  1   TotalSteps                457 non-null    int64
#  2   TotalDistance             457 non-null    float64
#  3   LoggedActivitiesDistance  457 non-null    float64
#  4   VeryActiveDistance        457 non-null    float64
#  5   ModeratelyActiveDistance  457 non-null    float64
#  6   LightActiveDistance       457 non-null    float64
#  7   SedentaryActiveDistance   457 non-null    float64
#  8   VeryActiveMinutes         457 non-null    int64
#  9   FairlyActiveMinutes       457 non-null    int64
#  10  LightlyActiveMinutes      457 non-null    int64
#  11  SedentaryMinutes          457 non-null    int64
#  12  Calories                  457 non-null    int64
# dtypes: float64(6), int64(6), object(1)
# ...

# %%
df.describe()
# Out:
#          TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# count    457.000000     457.000000                457.000000
# mean    6546.562363       4.663523                  0.179427
# std     5398.493064       4.082072                  0.849232
# min        0.000000       0.000000                  0.000000
# 25%     1988.000000       1.410000                  0.000000
# 50%     5986.000000       4.090000                  0.000000
# 75%    10198.000000       7.160000                  0.000000
# max    28497.000000      27.530001                  6.727057
#
#        VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# count          457.000000                457.000000           457.000000
# mean             1.180897                  0.478643             2.890197
# std              2.487159                  0.830995             2.237523
# min              0.000000                  0.000000             0.000000
# ...

# %% [markdown]
# df.isnull().sum()

# %% [markdown]
# ### Activity Data Vs Calories Burnt

# %%
### Activity Data Vs Calori Burntplt.figure(figsize=(12,6))
sns.barplot(x = 'ActivityDate', y = 'Calories', data=df)
# Allows you to rotate the X values to 90 degree.
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Activity Data Vs Total Steps

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'ActivityDate', y = 'TotalSteps', data=df)
# Allows you to rotate the X values to 90 degree.
plt.xticks(rotation=90)
plt.show()

# %%
Distance = df[['TotalSteps','TotalDistance']]
Distance
# Out:
#      TotalSteps  TotalDistance
# 0         11004       7.110000
# 1         17609      11.550000
# 2         12736       8.530000
# 3         13231       8.930000
# 4         12041       7.850000
# ..          ...            ...
# 452       23014      20.389999
# 453       16470       8.070000
# 454       28497      27.530001
# 455       10622       8.060000
# 456        2350       1.780000
#
# [457 rows x 2 columns]

# %%
Distance.plot(kind="bar",figsize=(16,4))
plt.title("Total Distance comparing Total Steps")
plt.show()

# %%
df
# Out:
#     ActivityDate  TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# 0      3/25/2016       11004       7.110000                       0.0
# 1      3/26/2016       17609      11.550000                       0.0
# 2      3/27/2016       12736       8.530000                       0.0
# 3      3/28/2016       13231       8.930000                       0.0
# 4      3/29/2016       12041       7.850000                       0.0
# ..           ...         ...            ...                       ...
# 452     4/8/2016       23014      20.389999                       0.0
# 453     4/9/2016       16470       8.070000                       0.0
# 454    4/10/2016       28497      27.530001                       0.0
# 455    4/11/2016       10622       8.060000                       0.0
# 456    4/12/2016        2350       1.780000                       0.0
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
df1 = df.head()
df1
# Out:
#   ActivityDate  TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# 0    3/25/2016       11004           7.11                       0.0
# 1    3/26/2016       17609          11.55                       0.0
# 2    3/27/2016       12736           8.53                       0.0
# 3    3/28/2016       13231           8.93                       0.0
# 4    3/29/2016       12041           7.85                       0.0
#
#    VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# 0                2.57                      0.46                 4.07
# 1                6.92                      0.73                 3.91
# 2                4.66                      0.16                 3.71
# 3                3.19                      0.79                 4.95
# 4                2.16                      1.09                 4.61
#
#    SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# 0                      0.0                 33                   12
# ...

# %% [markdown]
# ### Took top 5 data and plotted a Pie Chart comparing TotalSteps and Calories

# %%
df1.groupby(['TotalSteps']).sum().plot(kind='pie', y='Calories',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='Calories'>

# %% [markdown]
# ### Scatter Plot to define ActivityDate Vs Calories

# %%
x = df['ActivityDate']
y = df ['Calories']

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Line chart representinng total distance

# %%
y1 = np.array(df['TotalDistance'])

plt.plot(y1)

plt.show()
