# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.listdir("C:/Users/aravindv/Documents/programming/python/Vepsun-Excercises-Github/Vepsun-Python-Exercises/Titanic Analysis")
# Out:
# ['.ipynb_checkpoints',
#  'Titanic Analysis.ipynb',
#  'Titanic Case-study.pdf',
#  'Titanic.csv',
#  'Titanic.csv.csv']

# %% [markdown]
# ### Loading data on python using pandas library

# %%
data_frame = pd.read_csv(r"Titanic.csv")
data_frame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Print starting 10 rows of the data

# %%
data_frame.head(11)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Print last 10 rows of the data

# %%
data_frame.tail(11)
# Out:
#      PassengerId  Survived  Pclass  \
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 881                            Markun, Mr. Johann    male  33.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 884                        Sutehall, Mr. Henry Jr    male  25.0      0      0
# ...

# %% [markdown]
# ### Shape of the data

# %%
data_frame.shape
# Out:
# (891, 12)

# %%
data_frame.ndim
# Out:
# 2

# %%
data_frame.size
# Out:
# 10692

# %% [markdown]
# ### Print all columns name

# %%
data_frame.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Find the data type of all the columns

# %%
data_frame.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ###  Print information and summary

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data_frame.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Count Survived & Non Survived and show on pie chart

# %%
survived = data_frame["Survived"].value_counts()
survived
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.pie(survived, labels=["Not Survived", "Survived"], autopct= "%0.2f %%", colors = ["red", "green"], explode= (0,0.1),shadow =True)
plt.title ("Survived and Not Survived Passengers")
plt.legend(loc = "lower left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Find out how many female passengers had travelled in first class and show on pie  chart

# %%
female_class=data_frame[(data_frame.Sex=="female")].Pclass.value_counts()
female_class
# Out:
# 3    144
# 1     94
# 2     76
# Name: Pclass, dtype: int64

# %%
plt.pie(female_class, labels=["3rd", "1st", "2nd"], autopct= "%0.2f %%",explode=(0,0.1,0.1),shadow =True)
plt.title ("Female Passengers")
plt.legend(loc = "lower left")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Find out how many female passengers had Survived and her age <30, show on pie  chart and bar graph

# %% [markdown]
# ### Find out how many male passengers had Survived and his age >40, show on pie chart 11) Show age with 20 bins
